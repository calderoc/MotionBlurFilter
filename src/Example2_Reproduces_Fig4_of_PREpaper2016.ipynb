# %% [markdown]
# ## Jupyter notebook illustrating  commands required to use Python 2.7 modules provided and reproduces Fig 4 in Physical Review E Article:
#
# ###Motion Blur Filtering: A Statistical Approach for Extracting  Confinement Forces & Diffusivity from a Single Blurred Trajectory
#
# #####Author: Chris Calderon
#
# Copyright 2015 Ursa Analytics, Inc.
# Licensed under the Apache License, Version 2.0 (the "License");
# You may obtain a copy of the License at http://www.apache.org/licenses/LICENSE-2.0

# %% [markdown]
# ### Cell below loads the required modules and packages

# %%
# %matplotlib inline 
#command above avoids using the "dreaded" pylab flag when launching ipython (always put magic command above as first arg to ipynb file)

#load some standard scientific computing and plotting modules (code tested using Python 2.7.10, Scipy 0.15.1, and Matplotlib 1.4.3)
import numpy as np
import scipy.optimize as spo
import matplotlib.font_manager as font_manager
import matplotlib.pyplot as plt
####################################

#finally load custom modules provided with this repo
import findBerglundVersionOfMA1 #this module builds off of Berglund's 2010 PRE parameterization (atypical MA1 formulation)
import MotionBlurFilter
import Ursa_IPyNBpltWrapper

# %% [markdown]
# ##Now that required modules packages are loaded, set parameters for simulating "Blurred" OU trajectories.  Specific mixed continuous/discrete model:
#
# \begin{align}
# dr_t = & ({v}-{\kappa} r_t)dt + \sqrt{2 D}dB_t \\
# \psi_{t_i} = & \frac{1}{t_E}\int_{t_{i}-t_E}^{t_i} r_s ds + \epsilon^{\mathrm{loc}}_{t_i}
# \end{align}
#
# ###In above equations, parameter vector specifying model is: $\theta = (\kappa,D,\sigma_{\mathrm{loc}},v)$
#
#
# ###Statistically exact discretization of above for uniform time spacing  $\delta$  (non-uniform $\delta$ requires time dependent vectors and matrices below):
#
# \begin{align}
# r_{t_{i+1}} = & A + F r_{t_{i}} + \eta_{t_i} \\
# \psi_{t_i} = & H_A + H_Fr_{t_{i-1}} + \epsilon^{\mathrm{loc}}_{t_i} + \epsilon^{\mathrm{mblur}}_{t_i} \\
# \epsilon^{\mathrm{loc}}_{t_i} + & \epsilon^{\mathrm{mblur}}_{t_i} \sim  \mathcal{N}(0,R_i) \\
# \eta_i \sim & \mathcal{N}(0,Q) \\
# t_{i-1} = & t_{i}-t_E \\
#  C = & cov(\epsilon^{\mathrm{mblur}}_{t_i},\eta_{t_{i-1}}) \ne 0
# \end{align}
#
#
# ####Note:  Kalman Filter (KF) and Motion Blur Filter (MBF) codes estimate $\sqrt(2D)$ directly as "thermal noise" parameter

# %%
#set parameters determining state dynamics 
kappa = 1. # units: [1/s]
v = 0. #units [microns/s]
D = 0.1 #units [microns^2/s]
twoDsqrt = np.sqrt(D*2.) #filter codes provided (KF and MBF) estimate square root of 2D directly.


#parmeters determining trajectory length, uniform spacing in time, and number of trajectories to analyze 
#(Note: code is setup up to extract MLE on trajectorywise basis [trajectories not pooled])
T = 400 #length of each trajectory
delta = 25./1000. #spacing between observations.  code can be readily modified to handle non-uniform time spacing
Ntraj = 20 #number of trajectories to simulate and obtain MLE estimate (for quick illustration, can set to 1)
#(recommended to use notebook in small simulations and plots and write "production" script from modules provided)

#set parameters determining time dependent localization noise
#to simulate constant measurement noise just set sigF=sigB
sigF=60. #final localization in nm (state assumed to be in microns)
sigB=20. #initial localization in nm (state assumed to be in microns)
    
#set parameters for time dependent localization noise (simple exponential growth)
decay = -np.log(sigB/sigF)/T

Tsub = 100 #Parameter "numerically integrating" blur integral.  Exact OU process realized in simulations below, 
#however "Tsub" parameter used to empirically simulate blur.  This is done to demonstrate that closed-form 
#"blur" expressions derived in technical report are consistent with time integrated / averaged 
#data (avoids potential self fulfilling prophecy issues).  As mentioned in paper, camera readout and other nuances
#of optical microscopy likely to manifest before this dicretization errors crops up.

# %% [markdown]
# ###Cells below simulates "blurred" trajectories based on parameters defined above.  MLE, summary statistics of parameter distribution, and sample plots reproducing figure data also shown.

# %%
np.random.seed(0) #set seed to allow reproducible graphs and data compared to results presented in paper
myoptmeth='nelder-mead' #set optimization for MLE search (recommended to use nelder-mead due to highly nonlinear nature of MLE)

res1=[];res2=[];res3=[]; #variables for storing MLE parameters computed over Ntraj trajectory simulations
#res1 stores directed diffusion result (obtained using modified Berglund 2010 approach adding in constant velocity)
#res2 stores the Motion Blur Filter estimates
#res3 stores the classic KF estimates

for i in range(Ntraj):
    
    #print progress bar
    print '\n','^'*100 
    print 'Iteration ', i , '  ', '&'*50 
    print '^'*100 ,'\n\n'
    
    #setup storage for noise input (used for time varying and constant localization simulations)
    locNoiseNonStat=[];locNoiseNonStatMag=[]
    
    #setup vector providing true (possibly) nonstationary noise magnitude
    for t in range(T):
        noisemag = sigF*np.exp(-decay*(T-t)) 
        locNoiseNonStatMag.append(noisemag)
        locNoiseNonStat.append(np.random.randn(1)*noisemag/1000.)
        
    locNoiseNonStat = np.array(locNoiseNonStat) #cast list for processing
    locNoiseNonStatMag =  np.array(locNoiseNonStatMag) #cast list for processing
    
    #bias the intial guess from the known simulated truth above; motion blur MLE should converge to "offset" below in large T limit
    offset = 15./1000.
    locNoiseNonStatMagGuess = (locNoiseNonStatMag/1000. - offset) #input a biased "cramer rao type" guess in microns
    pars=(kappa,twoDsqrt, offset,v)
    
###Done setting up time dependent measurement noise input and noise realization ##############
    #now simulate one trajectory of process
    xrawfull,xrawsampled,xblur   = MotionBlurFilter.simTimeIntegratedOUdeltaICvel(pars,delta,Tsub,1,T)
    #output "xrawsampled" and "xblur" above gives T samples of trajectory;  former gives exact position at t_i
    #and latter gives "motion blurred" observation (using Tsub observations and assuming uniform continuous illumination)

    print "True Pars",pars #print true data generating process (DGP) parameters

    ymeas=xblur+locNoiseNonStat #add measurement noise to "perfectly blurred" trajectory

    MA=findBerglundVersionOfMA1.CostFuncMA1Diff(ymeas,delta) #initiate instance of class object finding Berglund parameters
    #note this esimator attemps to find \theta = (sqrtD, \sigma_loca, v) [KF and MBF code attempts to find sqrt(2D) and Bergrlund
    #code provide attempts to find sqrt(D)]

    XtrueMA= np.array([pars[1]/np.sqrt(2),pars[2],pars[3]]) #set the true parameters based on the known simulation parameters
    
    #seed MA1 search with low quality estimate of truth based on true known DGP parameter (multiple truth by factor of 1/2).
    res = spo.minimize(MA.evalCostFuncVel, XtrueMA/2., method='nelder-mead',options={'xtol': 1e-5, 'disp': False})

    #store and print result
    res1.append(res.x)
    print 'MA res',res.x[0]*np.sqrt(2),res.x[1],res.x[-1]
    print '-'*100

    #use crude estimate of mean reversion parameter.  see Calderon, PRE (2013)
    kappa1 = np.log(np.sum(ymeas[1:]*ymeas[0:-1])/(np.sum(ymeas[0:-1]**2)-T*res.x[1]**2))/-delta
    
    #set initial parameter guess for filter guess 
    parsIG=np.array([np.abs(kappa1),res.x[0]*np.sqrt(2),res.x[1],res.x[-1]]) #in practice, if reliable "StaticErrorEstSeq" provided, set offset par IG to zero.
    print 'parsIG for filters',parsIG
   
   
#   intitialize class object for filters of interest. setup code allowing for time varying noise to illustrate
#   the call sequence.  note: if optional "StaticErrorEstSeq" not defined, constant effective localization noise estimated.
    BlurF = MotionBlurFilter.ModifiedKalmanFilter1DwithCrossCorr(ymeas,delta,StaticErrorEstSeq=locNoiseNonStatMagGuess)
    KF = MotionBlurFilter.ClassicKalmanFilter(ymeas,delta,StaticErrorEstSeq=locNoiseNonStatMagGuess) #run side by side comparison of Rfixed and Rvarying
    
#   run KF MLE search (optmizatiion search for innovation MLE) with time varying or time constant noise    
    resKF = spo.minimize(KF.evalCostFunc,parsIG, method=myoptmeth)
    print 'KF result:', resKF
    res3.append(resKF.x)
    
    
    
#     parsIG2=np.array(np.hstack((np.array([resKF.x[0],res.x[0]*np.sqrt(2),.00]),resKF.x[-1])))
    parsIG2=parsIG #set initial parameter for motion blur filter 
    #(if comparing output, use same IG for both filters;  for produciton recommended to utilize KF drift pars for "warmer start")
    print 'parsIG for Motion Blur filter',parsIG2


#   run Motion Blur Filter search (optmizatiion search for innovation MLE) with time varying or time constant noise  
    resBlur = spo.minimize(BlurF.evalCostFunc,parsIG2, method=myoptmeth)
    res2.append(resBlur.x)
    print 'Motion Blur result:',resBlur
    
    
    print '*'*100
    print 'True DGP',pars
    
#   store relevant statistics and filter estimates evaluated at MLE
#   below "xfilt" corresponds to filtered state estimate 
#          "pit"  corresponds to PIT or generalized residual sequence evaluated at MLE
#          "Shist" correspond to variance of innovation sequence evaluated at MLE
#   suffix "2" after variable is used only to distinguish quantities computed with KF and MBF 
    loglike,xfilt,pit,Shist =KF.KFfilterOU1d(resKF.x) 
    loglike2,xfilt2,pit2,Shist2 =BlurF.KFfilterOU1d(resBlur.x)
    print '%'*100
    



    
    
    print 'run simple diagnostic check',np.std(pit),np.std(pit2)
    print 'correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] =',np.sqrt(1/12.)
    
#Box below outputs results of Ntraj optimizations
# Out:
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  0    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.424419388043 0.0410810726938 0.0040298554338
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.60199291  0.42441939  0.04108107  0.00402986]
# KF result:   status: 0
#     nfev: 388
#  success: True
#      fun: -1.1480290312612116
#        x: array([ 1.03433388,  0.41518035,  0.0076547 , -0.10360308])
#  message: 'Optimization terminated successfully.'
#      nit: 228
# parsIG for Motion Blur filter [ 0.60199291  0.42441939  0.04108107  0.00402986]
# Motion Blur result:   status: 0
#     nfev: 432
#  success: True
#      fun: -1.1533613356160182
#        x: array([ 1.10845331,  0.43149263,  0.01691706, -0.11266814])
#  message: 'Optimization terminated successfully.'
#      nit: 253
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.289415090115 0.289473176244
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  1    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.403073977313 0.0421150895907 0.031634085947
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.79916833  0.40307398  0.04211509  0.03163409]
# KF result:   status: 0
#     nfev: 258
#  success: True
#      fun: -1.1726865550174843
#        x: array([ 1.33446655,  0.39535597,  0.00919666, -0.04044342])
#  message: 'Optimization terminated successfully.'
#      nit: 154
# parsIG for Motion Blur filter [ 0.79916833  0.40307398  0.04211509  0.03163409]
# Motion Blur result:   status: 0
#     nfev: 321
#  success: True
#      fun: -1.1760118286665786
#        x: array([ 1.44069714,  0.41103521,  0.01766368, -0.04608614])
#  message: 'Optimization terminated successfully.'
#      nit: 182
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.292562913279 0.292064728609
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  2    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.42524643196 0.0383245946993 0.0340276497819
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.27322661  0.42524643  0.03832459  0.03402765]
# KF result:   status: 0
#     nfev: 408
#  success: True
#      fun: -1.1877379020142227
#        x: array([ 1.23263518,  0.41685864,  0.00196612,  0.47194591])
#  message: 'Optimization terminated successfully.'
#      nit: 237
# parsIG for Motion Blur filter [ 0.27322661  0.42524643  0.03832459  0.03402765]
# Motion Blur result:   status: 0
#     nfev: 305
#  success: True
#      fun: -1.1942812161107397
#        x: array([ 1.37928243,  0.44563069,  0.01179053,  0.52397514])
#  message: 'Optimization terminated successfully.'
#      nit: 183
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.292006630353 0.291016195887
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  3    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.387153259309 0.03907659817 -0.0101535859285
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.29604183  0.38715326  0.0390766  -0.01015359]
# KF result:   status: 0
#     nfev: 336
#  success: True
#      fun: -1.2205011120195504
#        x: array([ 1.13652651,  0.38750463,  0.00552843,  0.35588411])
#  message: 'Optimization terminated successfully.'
#      nit: 197
# parsIG for Motion Blur filter [ 0.29604183  0.38715326  0.0390766  -0.01015359]
# Motion Blur result:   status: 0
#     nfev: 449
#  success: True
#      fun: -1.2220005537614929
#        x: array([ 1.20262987,  0.40031652,  0.01525093,  0.3760108 ])
#  message: 'Optimization terminated successfully.'
#      nit: 269
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.287878053356 0.287044925796
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  4    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.373715660499 0.0414102651229 -0.0157864296324
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.60936283  0.37371566  0.04141027 -0.01578643]
# KF result:   status: 0
#     nfev: 276
#  success: True
#      fun: -1.1995754917041119
#        x: array([ 1.39577609,  0.39564183,  0.00698064, -0.15666091])
#  message: 'Optimization terminated successfully.'
#      nit: 157
# parsIG for Motion Blur filter [ 0.60936283  0.37371566  0.04141027 -0.01578643]
# Motion Blur result:   status: 0
#     nfev: 351
#  success: True
#      fun: -1.1972364794169159
#        x: array([ 1.42685754,  0.40062547,  0.01799129, -0.15973661])
#  message: 'Optimization terminated successfully.'
#      nit: 215
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.290997493225 0.289070924645
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  5    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.405656476422 0.0410263671093 -0.052681611196
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.88807495  0.40565648  0.04102637 -0.05268161]
# KF result:   status: 0
#     nfev: 285
#  success: True
#      fun: -1.1764269988628602
#        x: array([ 2.00860233,  0.41728314,  0.00527103, -0.20501555])
#  message: 'Optimization terminated successfully.'
#      nit: 167
# parsIG for Motion Blur filter [ 0.88807495  0.40565648  0.04102637 -0.05268161]
# Motion Blur result:   status: 0
#     nfev: 278
#  success: True
#      fun: -1.1785934866323897
#        x: array([ 2.20605279,  0.4374344 ,  0.01557274, -0.21988536])
#  message: 'Optimization terminated successfully.'
#      nit: 163
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.290100716111 0.29000976656
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  6    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.4402710132 0.0377964328685 0.0547347657674
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.51068635  0.44027101  0.03779643  0.05473477]
# KF result:   status: 0
#     nfev: 299
#  success: True
#      fun: -1.1620700984384336
#        x: array([ 0.92132446,  0.43105992,  0.00155962,  0.05992463])
#  message: 'Optimization terminated successfully.'
#      nit: 177
# parsIG for Motion Blur filter [ 0.51068635  0.44027101  0.03779643  0.05473477]
# Motion Blur result:   status: 0
#     nfev: 277
#  success: True
#      fun: -1.1646850755646905
#        x: array([ 1.00901608,  0.45080979,  0.01384756,  0.05966426])
#  message: 'Optimization terminated successfully.'
#      nit: 157
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.286513176838 0.285738393526
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  7    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.388132413403 0.0433411194926 -0.0185513629435
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 1.23144309  0.38813241  0.04334112 -0.01855136]
# KF result:   status: 0
#     nfev: 311
#  success: True
#      fun: -1.185907763390611
#        x: array([ 2.04481246,  0.38768676,  0.0101744 , -0.0579685 ])
#  message: 'Optimization terminated successfully.'
#      nit: 185
# parsIG for Motion Blur filter [ 1.23144309  0.38813241  0.04334112 -0.01855136]
# Motion Blur result:   status: 0
#     nfev: 321
#  success: True
#      fun: -1.1901666108724454
#        x: array([ 2.23796396,  0.40683236,  0.0176332 , -0.06167843])
#  message: 'Optimization terminated successfully.'
#      nit: 186
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.288250621775 0.287679030282
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  8    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.428119772401 0.036834081396 0.0630282787742
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.42503499  0.42811977  0.03683408  0.06302828]
# KF result:   status: 0
#     nfev: 290
#  success: True
#      fun: -1.1899168553549153
#        x: array([ 0.99371308,  0.41579456,  0.00189145,  0.1894635 ])
#  message: 'Optimization terminated successfully.'
#      nit: 168
# parsIG for Motion Blur filter [ 0.42503499  0.42811977  0.03683408  0.06302828]
# Motion Blur result:   status: 0
#     nfev: 301
#  success: True
#      fun: -1.1921480409110696
#        x: array([ 1.08745551,  0.43536162,  0.01343885,  0.19953405])
#  message: 'Optimization terminated successfully.'
#      nit: 173
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.286670896057 0.286377804378
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  9    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.403256456129 0.0448774684713 0.0326275280266
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.36723996  0.40325646  0.04487747  0.03262753]
# KF result:   status: 0
#     nfev: 292
#  success: True
#      fun: -1.1279530079401692
#        x: array([ 0.87170339,  0.40474291,  0.01225314,  0.18731035])
#  message: 'Optimization terminated successfully.'
#      nit: 172
# parsIG for Motion Blur filter [ 0.36723996  0.40325646  0.04487747  0.03262753]
# Motion Blur result:   status: 0
#     nfev: 328
#  success: True
#      fun: -1.1280944693418722
#        x: array([ 0.88568999,  0.40813124,  0.02201144,  0.19055841])
#  message: 'Optimization terminated successfully.'
#      nit: 198
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.290632525695 0.290215428276
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  10    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.446028885245 0.0386925712498 0.0317096491068
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.75851729  0.44602889  0.03869257  0.03170965]
# KF result:   status: 0
#     nfev: 350
#  success: True
#      fun: -1.1431276455558717
#        x: array([ 1.24012337,  0.43363579,  0.00443089,  0.10425922])
#  message: 'Optimization terminated successfully.'
#      nit: 209
# parsIG for Motion Blur filter [ 0.75851729  0.44602889  0.03869257  0.03170965]
# Motion Blur result:   status: 0
#     nfev: 354
#  success: True
#      fun: -1.1477995850384664
#        x: array([ 1.34154805,  0.45217825,  0.01547916,  0.11062196])
#  message: 'Optimization terminated successfully.'
#      nit: 208
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.28449169067 0.284895673478
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  11    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.434010744091 0.0405167804744 0.0160160696886
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.57109278  0.43401074  0.04051678  0.01601607]
# KF result:   status: 0
#     nfev: 296
#  success: True
#      fun: -1.1276963777632794
#        x: array([ 1.04291284,  0.43918291,  0.00535732,  0.09100988])
#  message: 'Optimization terminated successfully.'
#      nit: 175
# parsIG for Motion Blur filter [ 0.57109278  0.43401074  0.04051678  0.01601607]
# Motion Blur result:   status: 0
#     nfev: 348
#  success: True
#      fun: -1.1258718069653233
#        x: array([ 1.05351192,  0.44151478,  0.01909189,  0.09216535])
#  message: 'Optimization terminated successfully.'
#      nit: 205
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.287031319593 0.286381574216
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  12    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.442287440004 0.0413715103828 0.0900350458095
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.53980685  0.44228744  0.04137151  0.09003505]
# KF result:   status: 0
#     nfev: 325
#  success: True
#      fun: -1.1171397408170562
#        x: array([ 1.35682933,  0.43825527,  0.00708698,  0.16420762])
#  message: 'Optimization terminated successfully.'
#      nit: 191
# parsIG for Motion Blur filter [ 0.53980685  0.44228744  0.04137151  0.09003505]
# Motion Blur result:   status: 0
#     nfev: 276
#  success: True
#      fun: -1.1194332404848382
#        x: array([ 1.4467233 ,  0.44948185,  0.01867092,  0.17021473])
#  message: 'Optimization terminated successfully.'
#      nit: 165
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.287046045278 0.28655603207
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  13    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.434390132943 0.03929302448 0.025664302163
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.57814612  0.43439013  0.03929302  0.0256643 ]
# KF result:   status: 0
#     nfev: 308
#  success: True
#      fun: -1.1566977318604006
#        x: array([ 0.90366389,  0.4198275 ,  0.00507159, -0.00720397])
#  message: 'Optimization terminated successfully.'
#      nit: 190
# parsIG for Motion Blur filter [ 0.57814612  0.43439013  0.03929302  0.0256643 ]
# Motion Blur result:   status: 0
#     nfev: 326
#  success: True
#      fun: -1.1622391324566321
#        x: array([ 0.99018985,  0.44116786,  0.01483986, -0.01123828])
#  message: 'Optimization terminated successfully.'
#      nit: 194
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.2927221405 0.292304216987
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  14    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.41172511793 0.0381906244757 0.0140346857554
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.60104658  0.41172512  0.03819062  0.01403469]
# KF result:   status: 0
#     nfev: 317
#  success: True
#      fun: -1.1773538573798994
#        x: array([  1.18067347e+00,   4.36851335e-01,  -1.01333220e-03,
#          1.04753219e-01])
#  message: 'Optimization terminated successfully.'
#      nit: 194
# parsIG for Motion Blur filter [ 0.60104658  0.41172512  0.03819062  0.01403469]
# Motion Blur result:   status: 0
#     nfev: 350
#  success: True
#      fun: -1.1694922159159038
#        x: array([ 1.11384468,  0.42298466,  0.01809248,  0.09968467])
#  message: 'Optimization terminated successfully.'
#      nit: 213
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.285927048068 0.283652356975
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  15    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.449857260655 0.0346579356844 -0.00961815222567
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.88913675  0.44985726  0.03465794 -0.00961815]
# KF result:   status: 0
#     nfev: 314
#  success: True
#      fun: -1.1657356007483743
#        x: array([ 1.46828018,  0.46109849, -0.00702384, -0.01069829])
#  message: 'Optimization terminated successfully.'
#      nit: 183
# parsIG for Motion Blur filter [ 0.88913675  0.44985726  0.03465794 -0.00961815]
# Motion Blur result:   status: 0
#     nfev: 348
#  success: True
#      fun: -1.1617782112311523
#        x: array([ 1.49673122,  0.466074  ,  0.01368125, -0.01187433])
#  message: 'Optimization terminated successfully.'
#      nit: 206
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.286852082731 0.285266530523
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  16    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.405800956031 0.0429519978439 0.0281939741469
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.79926389  0.40580096  0.042952    0.02819397]
# KF result:   status: 0
#     nfev: 306
#  success: True
#      fun: -1.1525958636923403
#        x: array([ 1.6940945 ,  0.40522956,  0.01038523, -0.19948283])
#  message: 'Optimization terminated successfully.'
#      nit: 179
# parsIG for Motion Blur filter [ 0.79926389  0.40580096  0.042952    0.02819397]
# Motion Blur result:   status: 0
#     nfev: 306
#  success: True
#      fun: -1.1566192304247196
#        x: array([ 1.80761864,  0.41859516,  0.01897437, -0.21483717])
#  message: 'Optimization terminated successfully.'
#      nit: 180
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.28864079935 0.288461645606
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  17    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.480288977474 0.0331514881721 -0.0363681915976
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.44076703  0.48028898  0.03315149 -0.03636819]
# KF result:   status: 0
#     nfev: 302
#  success: True
#      fun: -1.1567055773671833
#        x: array([ 0.75616247,  0.44584531, -0.00291845,  0.08976481])
#  message: 'Optimization terminated successfully.'
#      nit: 176
# parsIG for Motion Blur filter [ 0.44076703  0.48028898  0.03315149 -0.03636819]
# Motion Blur result:   status: 0
#     nfev: 276
#  success: True
#      fun: -1.1667980253560757
#        x: array([ 0.90484103,  0.48724581,  0.00819062,  0.11626712])
#  message: 'Optimization terminated successfully.'
#      nit: 161
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.288004627576 0.288305198814
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  18    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.401116762795 0.0394385428325 -0.0153834632654
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.75943206  0.40111676  0.03943854 -0.01538346]
# KF result:   status: 0
#     nfev: 358
#  success: True
#      fun: -1.1843201269595836
#        x: array([ 1.38531102,  0.41246203,  0.00504919, -0.10920526])
#  message: 'Optimization terminated successfully.'
#      nit: 211
# parsIG for Motion Blur filter [ 0.75943206  0.40111676  0.03943854 -0.01538346]
# Motion Blur result:   status: 0
#     nfev: 325
#  success: True
#      fun: -1.1826562452707408
#        x: array([ 1.41275493,  0.41718326,  0.01732855, -0.11048083])
#  message: 'Optimization terminated successfully.'
#      nit: 192
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.288690757993 0.288564999939
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595
#
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# Iteration  19    &&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&&
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# True Pars (1.0, 0.44721359549995793, 0.015, 0.0)
# MA res 0.467777026062 0.0341303275126 0.00955821835764
# ----------------------------------------------------------------------------------------------------
# parsIG for filters [ 0.47172055  0.46777703  0.03413033  0.00955822]
# KF result:   status: 0
#     nfev: 369
#  success: True
#      fun: -1.1514579596193353
#        x: array([ 0.98014051,  0.46062703, -0.00593545,  0.19836089])
#  message: 'Optimization terminated successfully.'
#      nit: 219
# parsIG for Motion Blur filter [ 0.47172055  0.46777703  0.03413033  0.00955822]
# Motion Blur result:   status: 0
#     nfev: 294
#  success: True
#      fun: -1.1464820601073715
#        x: array([ 1.01450706,  0.46829234,  0.01419474,  0.20914752])
#  message: 'Optimization terminated successfully.'
#      nit: 175
# ****************************************************************************************************
# True DGP (1.0, 0.44721359549995793, 0.015, 0.0)
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# run simple diagnostic check 0.295173948512 0.293260633301
# correctly specied large sample PIT sequence should have std of uniform r.v. on [0,1] = 0.288675134595

# %%
#Summarize the results of the above Ntraj simulations (increase Ntraj to get more precise MLE par distributions)
#
#this block is useful for when one wishes to explore statistical MLE performance under different parameters and
#sampling conditions

resSUM=np.array(res2)
print 'Blur medians',np.median(resSUM[:,0]),np.median(resSUM[:,1]),np.median(resSUM[:,2]),np.median(resSUM[:,3])
print 'means',np.mean(resSUM[:,0]),np.mean(resSUM[:,1]),np.mean(resSUM[:,2]),np.mean(resSUM[:,3])
print 'std',np.std(resSUM[:,0]),np.std(resSUM[:,1]),np.std(resSUM[:,2]),np.std(resSUM[:,3])

print '^'*100 ,'\n\n'

resSUM=np.array(res3)
print 'KF medians',np.median(resSUM[:,0]),np.median(resSUM[:,1]),np.median(resSUM[:,2]),np.median(resSUM[:,3])
print 'means',np.mean(resSUM[:,0]),np.mean(resSUM[:,1]),np.mean(resSUM[:,2]),np.mean(resSUM[:,3])
print 'std',np.std(resSUM[:,0]),np.std(resSUM[:,1]),np.std(resSUM[:,2]),np.std(resSUM[:,3])

print '*'*100
print 'True DGP Parameters',pars
# Out:
# Blur medians 1.27208896048 0.436398012298 0.0162448981391 0.0759148071562
# means 1.32831846488 0.434619396439 0.016033054753 0.0599679357854
# std 0.376557503684 0.0234226972374 0.00299112054823 0.185972525712
# ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
#
# KF medians 1.20665432544 0.417070891424 0.00517130917218 0.074844720189
# means 1.24910427587 0.42100619691 0.00414831642154 0.0563301168525
# std 0.344318677125 0.0213863714616 0.00510562491792 0.173086891275
# ****************************************************************************************************
# True DGP Parameters (1.0, 0.44721359549995793, 0.015, 0.0)

# %% [markdown]
# ### Now plot results mentioned in Notebook Title

# %%
#plot measurement noise

fig,ax,pltPars = Ursa_IPyNBpltWrapper.basicPltSetup(axisfontsize='22') #standard plot

t1=np.arange(len(locNoiseNonStatMagGuess))*delta
inputNoise = locNoiseNonStatMagGuess*1000
grey = (148/255., 148/255., 156/255.) #set custom RGB color
correctedNoise = (locNoiseNonStatMagGuess +  resBlur.x[2])*1000
ax.plot(t1,inputNoise,'-',linewidth=5,label='Input Loc. Est.',color=grey)
ax.plot(t1,correctedNoise,'r--',linewidth=4,label='MBF Refined Loc. Est.')

correctedNoise2 = (locNoiseNonStatMagGuess +  resKF.x[2])*1000
ax.plot(t1,correctedNoise2,'b.-',linewidth=4,label='KF Refined Loc. Est.')
ax.plot(t1,locNoiseNonStatMag,'k-',label='True Localization Mag.',linewidth=5)
ax.plot(t1,correctedNoise,'r--',linewidth=4) #replot to overlay

#tweak graph limits and appearance
ax.set_ylim([-5,100])
ax.yaxis.set_ticks(np.arange(0,120,20))
# ax.set_xlim([0,1000])
# ax.xaxis.set_ticks(np.arange(0,1100,200))
ax.set_xlim([0,10])
ax.xaxis.set_ticks(np.arange(0,12,2))

# lgd = ax.legend(loc='upper left', fancybox=True, framealpha=0.5,ncol=1,numpoints=1,prop=pltPars['leg_prop'],labelspacing=.2)
#Note call above requires some OS specific tweaks.  this font adjustment has been removed, but the data displayed is identitical
lgd = ax.legend(loc='upper left', fancybox=True, framealpha=0.5,ncol=1,numpoints=1,labelspacing=.2)

Ursa_IPyNBpltWrapper.xyLabels(ax,pltPars,xlabel='',ylabel='') #adjust font style and size in main plot (Helvetica default)

#save fig
# fig.savefig('Example2_RinputBiasCorr' + '.png',dpi=600)
# Out:
# /home/calderoc/tutorial-env/lib/python2.7/site-packages/matplotlib/font_manager.py:1282: UserWarning: findfont: Font family [u'Arial'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
#now consider option for combining x-axis in secondary plots

#setup trajectory and MSD plot in shared x-axis plot
fig,ax,axTop,pltPars = Ursa_IPyNBpltWrapper.sharedXPltSetup(axisfontsize='22',legendfontsize='18')

#setup grid for blur and fully sampled state
t1=np.arange(xrawsampled.shape[0])
t1sub = np.arange(xrawfull.shape[0])/float(Tsub)
t2=(t1+.5)*delta #evaluate at midpoint as well 
t1=(t1+1)*delta #xrawsampled is at endpoint (done to keep xblur and xrawsampled same size)


print t1sub.shape,xrawfull.shape
neongreen=[51/255., 214/255., 51/255.]
vKF=[];vB=[];vTrue=[]; #store velocity information
ix = 0
axTop.plot(t2,ymeas[:,ix],'-', label='Meas. Pos.',color=neongreen,linewidth=3)
# axTop.plot(t1,xrawsampled[:,ix],'-', label='Meas. Pos.',color=grey)

L = np.sqrt(6*(twoDsqrt)**2/kappa)



vB.append(-xfilt2*resBlur.x[0]+resBlur.x[-1])
vKF.append(-xfilt*resKF.x[0]+resKF.x[-1])
vTrue.append(-xrawsampled[:,ix]*pars[0]+pars[-1])

#tweak graph limits and appearance
axTop.set_ylim([-1,1])
axTop.set_xlim([0,400])
axTop.yaxis.set_ticks(np.arange(-1.,1.5,.5))

Ursa_IPyNBpltWrapper.xyLabels(axTop,pltPars,xlabel='',ylabel='') #adjust font style and size in main plot (Helvetica default)



tlag = np.arange(1,T,10)
tlag,MSD = findBerglundVersionOfMA1.MSD(ymeas,tlag)
tlag = tlag*delta

ax.plot(tlag,MSD,'-',linewidth=3,label='MSD Empirical')
print pars,resBlur.x
ax.plot(tlag,np.ones(len(MSD))*(L**2/6.),'r--',linewidth=5,label='$L^2/6$')
print L*1000



#print the MSD estimate using the last 3/4 of MSD [not unreasonable given shape, but 
#usually MSD truncation is typically quite heuristic with the "lag cutoff"; this adds additional error on top of time aggregation ]
print 'MSD mean', np.mean(np.array(MSD[25:]))

#tweak graph limits and appearance

ax.set_xlim([0,10])
ax.xaxis.set_ticks(np.arange(0,12,2))
ax.set_ylim([-.01,.7])
ax.yaxis.set_ticks(np.arange(.1,.70,.2))

lgd = ax.legend(loc='upper center', fancybox=True, framealpha=0.5,ncol=2,numpoints=1,labelspacing=.1)
Ursa_IPyNBpltWrapper.xyLabels(ax,pltPars,xlabel='',ylabel='') #adjust font style and size in main plot (Helvetica default)

# fig.savefig('Example2_MSDandTraj' + '.png',dpi=600)
# Out:
# (40000,) (40000, 1)
# (1.0, 0.44721359549995793, 0.015, 0.0) [ 1.01450706  0.46829234  0.01419474  0.20914752]
# 1095.44511501
# MSD mean 0.159593752737
